# %%
import os
import random
import torch
from torch import nn
from torch.utils.data import TensorDataset, Dataset

import numpy as np 
import pickle
import matplotlib.pyplot as plt
import time
import copy

from sklearn.model_selection import train_test_split
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

random_seed = 1
random.seed(random_seed)
np.random.seed(random_seed)
torch.manual_seed(random_seed)

from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter('runs/gnn')

# %% [markdown]
# # Load data and normalize

# %%
X = pickle.load(open('../dataset/train/cross_subject_data_5_subjects.pickle', 'rb'))
y = X['train_y']

X = X['train_x'].astype(np.float32)

label_map = {'imagine_both_feet': 0, 'imagine_both_fist': 1, 'imagine_left_fist': 2, 'imagine_right_fist': 3}
y = np.vectorize(label_map.__getitem__)(y)

# %%
# Normalize
mean, std = X.mean(), X.std()
X = (X - mean) / std

# %% [markdown]
# # Import Adj Matrix

# %%
from convert_to_graphs import n_graph, d_graph, s_graph, normalize_adj

seq_len = 100
n_channels = 64
batch_size = 32

A = n_graph()
A = np.array(A, dtype=np.float32)
A = normalize_adj(A)
A = A + np.eye(A.shape[0], dtype=np.float32)


A_big = np.zeros((n_channels*batch_size, n_channels*batch_size), dtype=np.float32)
print(A_big.shape)
for i in range(0, A_big.shape[0], n_channels):
    A_big[i:i+n_channels, i:i+n_channels] = A

# A_bigger = []
# for i in range(batch_size):
#     A_bigger.append(A_big)

# A_bigger = np.array(A_bigger, dtype=np.float32)

A = torch.Tensor(A_big).to(device)

print('Adjacency Matrix A:')
print(A.shape)
# Out:
# (2048, 2048)
# Adjacency Matrix A:
# torch.Size([2048, 2048])

# %%
# import mne 
# import pandas as pd
# import numpy as np 

# ten_twenty_montage = mne.channels.make_standard_montage("standard_1020")
# ch_names = pd.read_csv("../dataset/physionet.org_csv/S001/S001R01.csv")
# ch_names = ch_names.columns[2:]

# ch_pos_1020 = ten_twenty_montage.get_positions()["ch_pos"]

# ch_pos_1010 = {}
# for ch_name_orig in ch_names:
#     ch_name = ch_name_orig.upper().rstrip(".")
#     if "Z" in ch_name:
#         ch_name = ch_name.replace("Z", "z")
#     if "P" in ch_name and len(ch_name) > 2:
#         ch_name = ch_name.replace("P", "p")
#     if "Cp" in ch_name:
#         ch_name = ch_name.replace("Cp", "CP")
#     if "Tp" in ch_name:
#         ch_name = ch_name.replace("Tp", "TP")
#     if "pO" in ch_name:
#         ch_name = ch_name.replace("pO", "PO")
#     ch_pos_1010[ch_name_orig] = ch_pos_1020[ch_name]
# print(len(ch_pos_1010))

# ch_pos_1010_names = []
# ch_pos_1010_dist = []
# for name, value in ch_pos_1010.items():
#     ch_pos_1010_names.append(name)
#     ch_pos_1010_dist.append(value)
# ch_pos_1010_dist = np.array(ch_pos_1010_dist)

# A = d_graph(n_channels, ch_pos_1010_dist)
# A = np.array(A, dtype=np.float32)

# A = normalize_adj(A)
# A = A + np.eye(A.shape[0], dtype=np.float32)


# A_big = np.zeros((n_channels*batch_size, n_channels*batch_size), dtype=np.float32)
# print(A_big.shape)
# for i in range(0, A_big.shape[0], n_channels):
#     A_big[i:i+n_channels, i:i+n_channels] = A

# # A_bigger = []
# # for i in range(batch_size):
# #     A_bigger.append(A_big)

# # A_bigger = np.array(A_bigger, dtype=np.float32)

# A = torch.Tensor(A_big).to(device)

# print('Adjacency Matrix A:')
# print(A.shape)

# %% [markdown]
# # Convert data to [n_samples, n_channels] -> [n_samples, seq_len, n_channels]

# %%
# def reshape_data_gnn(X, y, seq_len):
#     print('X original shape:', X.shape)
#     print('y original shape:', y.shape)
#     print('Seq len:', seq_len)
#     len_tail = X.shape[0] % seq_len
#     if len_tail == 0:
#         X = X.reshape(-1, seq_len*n_channels, 1)
#         y = y.reshape(-1, seq_len)
#     else:
#         X = X[:-len_tail].reshape(-1, seq_len*n_channels, 1)
#         y = y[:-len_tail].reshape(-1, seq_len)
#     y = y[:, -1]
#     print('X conversion shape:', X.shape)
#     print('y conversion shape:', y.shape)
#     return X, y

def reshape_data_gnn_2(X, y, seq_len):
    print('X original shape:', X.shape)
    print('y original shape:', y.shape)
    print('Seq len:', seq_len)
    len_tail = X.shape[0] % seq_len
    if len_tail == 0:
        X = X.reshape(-1, seq_len, n_channels)
        X = np.moveaxis(X, 1, -1)
        y = y.reshape(-1, seq_len)
    else:
        X = X[:-len_tail].reshape(-1, seq_len, n_channels)
        X = np.moveaxis(X, 1, -1)
        y = y[:-len_tail].reshape(-1, seq_len)
    y = y[:, -1]
    print('X conversion shape:', X.shape)
    print('y conversion shape:', y.shape)
    return X, y

X, y = reshape_data_gnn_2(X, y, seq_len)
# Out:
# X original shape: (295008, 64)
# y original shape: (295008,)
# Seq len: 100
# X conversion shape: (2950, 64, 100)
# y conversion shape: (2950,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed, stratify=y)
def print_class_dist(y):
    dist = {}

    labels = np.unique(y)
    for label in labels:
        dist[str(label)] = len(y[y == label]) / len(y)
    print(dist)
print_class_dist(y)
print_class_dist(y_train)
print_class_dist(y_test)
# Out:
# {'0': 0.24745762711864408, '1': 0.25254237288135595, '2': 0.25864406779661014, '3': 0.24135593220338983}
# {'0': 0.24745762711864408, '1': 0.25254237288135595, '2': 0.2584745762711864, '3': 0.24152542372881355}
# {'0': 0.24745762711864408, '1': 0.25254237288135595, '2': 0.2593220338983051, '3': 0.24067796610169492}

# %%
X_train, y_train = torch.tensor(X_train).to(device), torch.tensor(y_train).to(device)
X_test, y_test = torch.tensor(X_test).to(device), torch.tensor(y_test).to(device)

train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, drop_last=True)

dataset_sizes = {'train': len(train_dataset), 'val': len(test_dataset)}
dataloaders = {'train': train_loader, 'val': test_loader}
class_names = list(label_map.keys())
print(class_names)
# Out:
# ['imagine_both_feet', 'imagine_both_fist', 'imagine_left_fist', 'imagine_right_fist']

# %%
def train_model(model, criterion, optimizer, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs-1}')
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0.0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            writer.add_scalar(f'{phase} loss', epoch_loss, epoch)
            writer.add_scalar(f'{phase} accuracy', epoch_acc, epoch)

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed%60:.0f}s')
    print(f'Best val acc: {best_acc:.4f}')

    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# # Test computation

# %%
# import time
# import torch
# from layers_original import GraphConvolution

# torch.manual_seed(0)
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# x = torch.randn(16, 64, 32).to(device)
# x = x.view(-1, 32)
# # A = torch.randn(16*64, 16*64).to(device)
# # weight = torch.randn(32, 512).to(device)
# # A = A.to_sparse()
# print(A.is_sparse)
# gcn = GraphConvolution(32, 128).to(device)
# now = time.time()

# out = gcn(x, A)
# print(out.shape)
# out = out.view(16, 64, 128)
# # support = torch.matmul(x, weight)
# # output = torch.bmm(A, support)
# print(out.shape)
# print('elapsed time:', time.time() - now)

# %%
in_features = seq_len
hidden_size_1 = 2048
hidden_size_2 = 4096
hidden_size_3 = 2048
hidden_size_4 = 1024
num_classes = 4
num_epochs = 100

# from layers_batchwise import BatchwiseGraphConvolution
from layers_batchwise_2 import GraphConvolution
import torch.nn.functional as F

class GCN(nn.Module):
    def __init__(self, in_features, hidden_size_1, hidden_size_2, num_classes):
        super(GCN, self).__init__()
        self.gc1 = GraphConvolution(in_features, hidden_size_1, batch_size, n_channels)
        self.gc2 = GraphConvolution(hidden_size_1, hidden_size_2, batch_size, n_channels)
        self.gc3 = GraphConvolution(hidden_size_2, hidden_size_3, batch_size, n_channels)
        self.gc4 = GraphConvolution(hidden_size_3, hidden_size_4, batch_size, n_channels)
        self.flatten = nn.Flatten()
        self.linear = nn.Linear(hidden_size_4*n_channels, num_classes)
    def forward(self, x):
        # print(x.shape)
        out = F.relu(self.gc1(x, A))
        # print(out.shape)
        out = F.relu(self.gc2(out, A))
        # print(out.shape)
        out = F.relu(self.gc3(out, A))
        # print(out.shape)
        out = F.relu(self.gc4(out, A))
        # print(out.shape)
        out = self.flatten(out)
        # print(out.shape)
        out = self.linear(out)
        # print(out.shape)
        return out

model = GCN(in_features, hidden_size_1, hidden_size_2, num_classes).to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# writer.add_graph(model, X_train[:batch_size])

# %%
X.shape
# Out:
# (2950, 64, 100)

# %%
model = train_model(model, criterion, optimizer, num_epochs=num_epochs)
# Out:
# Epoch 0/99
# ----------
# train Loss: 2.3078 Acc: 0.2530
# val Loss: 1.3605 Acc: 0.2441
#
# Epoch 1/99
# ----------
# train Loss: 1.3844 Acc: 0.2534
# val Loss: 1.3644 Acc: 0.2627
#
# Epoch 2/99
# ----------
# train Loss: 1.3756 Acc: 0.2508
# val Loss: 1.3531 Acc: 0.2508
#
# Epoch 3/99
# ----------
# train Loss: 1.3724 Acc: 0.2534
# val Loss: 1.3532 Acc: 0.2475
#
# Epoch 4/99
# ----------
# train Loss: 1.3724 Acc: 0.2462
# val Loss: 1.3531 Acc: 0.2525
#
# Epoch 5/99
# ----------
# train Loss: 1.3775 Acc: 0.2487
# val Loss: 1.3552 Acc: 0.2492
#
# Epoch 6/99
# ----------
# train Loss: 1.3720 Acc: 0.2525
# val Loss: 1.3526 Acc: 0.2458
#
# Epoch 7/99
# ----------
# train Loss: 1.3729 Acc: 0.2572
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 8/99
# ----------
# train Loss: 1.3719 Acc: 0.2568
# val Loss: 1.3530 Acc: 0.2475
#
# Epoch 9/99
# ----------
# train Loss: 1.3712 Acc: 0.2614
# val Loss: 1.3532 Acc: 0.2458
#
# Epoch 10/99
# ----------
# train Loss: 1.3731 Acc: 0.2581
# val Loss: 1.3630 Acc: 0.2492
#
# Epoch 11/99
# ----------
# train Loss: 1.3694 Acc: 0.2589
# val Loss: 1.3528 Acc: 0.2441
#
# Epoch 12/99
# ----------
# train Loss: 1.3713 Acc: 0.2525
# val Loss: 1.3532 Acc: 0.2492
#
# Epoch 13/99
# ----------
# train Loss: 1.3725 Acc: 0.2555
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 14/99
# ----------
# train Loss: 1.3720 Acc: 0.2572
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 15/99
# ----------
# train Loss: 1.3719 Acc: 0.2568
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 16/99
# ----------
# train Loss: 1.3720 Acc: 0.2547
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 17/99
# ----------
# train Loss: 1.3721 Acc: 0.2538
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 18/99
# ----------
# train Loss: 1.3720 Acc: 0.2538
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 19/99
# ----------
# train Loss: 1.3720 Acc: 0.2576
# val Loss: 1.3530 Acc: 0.2542
#
# Epoch 20/99
# ----------
# train Loss: 1.3718 Acc: 0.2576
# val Loss: 1.3529 Acc: 0.2508
#
# Epoch 21/99
# ----------
# train Loss: 1.3709 Acc: 0.2572
# val Loss: 1.3532 Acc: 0.2441
#
# Epoch 22/99
# ----------
# train Loss: 1.3679 Acc: 0.2606
# val Loss: 1.3602 Acc: 0.2407
#
# Epoch 23/99
# ----------
# train Loss: 1.3696 Acc: 0.2640
# val Loss: 1.3610 Acc: 0.2373
#
# Epoch 24/99
# ----------
# train Loss: 1.3650 Acc: 0.2627
# val Loss: 1.3649 Acc: 0.2441
#
# Epoch 25/99
# ----------
# train Loss: 1.3682 Acc: 0.2627
# val Loss: 1.3529 Acc: 0.2508
#
# Epoch 26/99
# ----------
# train Loss: 1.3636 Acc: 0.2602
# val Loss: 1.3831 Acc: 0.2424
#
# Epoch 27/99
# ----------
# train Loss: 1.3683 Acc: 0.2602
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 28/99
# ----------
# train Loss: 1.3721 Acc: 0.2564
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 29/99
# ----------
# train Loss: 1.3717 Acc: 0.2568
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 30/99
# ----------
# train Loss: 1.3714 Acc: 0.2555
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 31/99
# ----------
# train Loss: 1.3713 Acc: 0.2564
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 32/99
# ----------
# train Loss: 1.3717 Acc: 0.2521
# val Loss: 1.3530 Acc: 0.2492
#
# Epoch 33/99
# ----------
# train Loss: 1.3710 Acc: 0.2517
# val Loss: 1.3530 Acc: 0.2525
#
# Epoch 34/99
# ----------
# train Loss: 1.3708 Acc: 0.2581
# val Loss: 1.3542 Acc: 0.2492
#
# Epoch 35/99
# ----------
# train Loss: 1.3680 Acc: 0.2627
# val Loss: 1.3783 Acc: 0.2492
#
# Epoch 36/99
# ----------
# train Loss: 1.3643 Acc: 0.2648
# val Loss: 1.3544 Acc: 0.2475
#
# Epoch 37/99
# ----------
# train Loss: 1.3630 Acc: 0.2665
# val Loss: 1.3635 Acc: 0.2475
#
# Epoch 38/99
# ----------
# train Loss: 1.3604 Acc: 0.2581
# val Loss: 1.3569 Acc: 0.2407
#
# Epoch 39/99
# ----------
# train Loss: 1.3704 Acc: 0.2555
# val Loss: 1.3530 Acc: 0.2492
#
# Epoch 40/99
# ----------
# train Loss: 1.3618 Acc: 0.2547
# val Loss: 1.3718 Acc: 0.2542
#
# Epoch 41/99
# ----------
# train Loss: 1.3626 Acc: 0.2682
# val Loss: 1.3717 Acc: 0.2525
#
# Epoch 42/99
# ----------
# train Loss: 1.3532 Acc: 0.2703
# val Loss: 1.3518 Acc: 0.2542
#
# Epoch 43/99
# ----------
# train Loss: 1.3605 Acc: 0.2720
# val Loss: 1.3674 Acc: 0.2492
#
# Epoch 44/99
# ----------
# train Loss: 1.3499 Acc: 0.2746
# val Loss: 1.3667 Acc: 0.2525
#
# Epoch 45/99
# ----------
# train Loss: 1.3445 Acc: 0.2742
# val Loss: 1.3670 Acc: 0.2559
#
# Epoch 46/99
# ----------
# train Loss: 1.3460 Acc: 0.2720
# val Loss: 1.3626 Acc: 0.2542
#
# Epoch 47/99
# ----------
# train Loss: 1.3419 Acc: 0.2758
# val Loss: 1.4285 Acc: 0.2339
#
# Epoch 48/99
# ----------
# train Loss: 1.3369 Acc: 0.2716
# val Loss: 1.4600 Acc: 0.2542
#
# Epoch 49/99
# ----------
# train Loss: 1.3369 Acc: 0.2797
# val Loss: 1.3733 Acc: 0.2475
#
# Epoch 50/99
# ----------
# train Loss: 1.3365 Acc: 0.2780
# val Loss: 1.6295 Acc: 0.2559
#
# Epoch 51/99
# ----------
# train Loss: 1.3435 Acc: 0.2788
# val Loss: 1.3814 Acc: 0.2525
#
# Epoch 52/99
# ----------
# train Loss: 1.3446 Acc: 0.2754
# val Loss: 1.4480 Acc: 0.2542
#
# Epoch 53/99
# ----------
# train Loss: 1.3457 Acc: 0.2775
# val Loss: 1.4431 Acc: 0.2339
#
# Epoch 54/99
# ----------
# train Loss: 1.3347 Acc: 0.2691
# val Loss: 1.3517 Acc: 0.2559
#
# Epoch 55/99
# ----------
# train Loss: 1.3476 Acc: 0.2716
# val Loss: 1.4022 Acc: 0.2525
#
# Epoch 56/99
# ----------
# train Loss: 1.3403 Acc: 0.2767
# val Loss: 1.3690 Acc: 0.2525
#
# Epoch 57/99
# ----------
# train Loss: 1.3386 Acc: 0.2814
# val Loss: 1.4684 Acc: 0.2508
#
# Epoch 58/99
# ----------
# train Loss: 1.3419 Acc: 0.2754
# val Loss: 1.3808 Acc: 0.2593
#
# Epoch 59/99
# ----------
# train Loss: 1.3345 Acc: 0.2801
# val Loss: 1.5138 Acc: 0.2593
#
# Epoch 60/99
# ----------
# train Loss: 1.3348 Acc: 0.2797
# val Loss: 1.4269 Acc: 0.2559
#
# Epoch 61/99
# ----------
# train Loss: 1.3399 Acc: 0.2797
# val Loss: 1.5417 Acc: 0.2559
#
# Epoch 62/99
# ----------
# train Loss: 1.3457 Acc: 0.2716
# val Loss: 1.6250 Acc: 0.2542
#
# Epoch 63/99
# ----------
# train Loss: 1.3406 Acc: 0.2873
# val Loss: 1.5349 Acc: 0.2542
#
# Epoch 64/99
# ----------
# train Loss: 1.3212 Acc: 0.2852
# val Loss: 1.6904 Acc: 0.2593
#
# Epoch 65/99
# ----------
# train Loss: 1.3249 Acc: 0.2843
# val Loss: 1.6291 Acc: 0.2458
#
# Epoch 66/99
# ----------
# train Loss: 1.3244 Acc: 0.2864
# val Loss: 1.7408 Acc: 0.2593
#
# Epoch 67/99
# ----------
# train Loss: 1.3159 Acc: 0.2886
# val Loss: 1.8253 Acc: 0.2576
#
# Epoch 68/99
# ----------
# train Loss: 1.3444 Acc: 0.2763
# val Loss: 1.4782 Acc: 0.2576
#
# Epoch 69/99
# ----------
# train Loss: 1.3441 Acc: 0.2750
# val Loss: 1.4175 Acc: 0.2559
#
# Epoch 70/99
# ----------
# train Loss: 1.3368 Acc: 0.2780
# val Loss: 1.4233 Acc: 0.2559
#
# Epoch 71/99
# ----------
# train Loss: 1.3334 Acc: 0.2775
# val Loss: 1.4411 Acc: 0.2542
#
# Epoch 72/99
# ----------
# train Loss: 1.3297 Acc: 0.2831
# val Loss: 1.5265 Acc: 0.2576
#
# Epoch 73/99
# ----------
# train Loss: 1.3233 Acc: 0.2822
# val Loss: 1.6190 Acc: 0.2576
#
# Epoch 74/99
# ----------
# train Loss: 1.3339 Acc: 0.2831
# val Loss: 1.6900 Acc: 0.2576
#
# Epoch 75/99
# ----------
# train Loss: 1.3334 Acc: 0.2758
# val Loss: 1.4470 Acc: 0.2525
#
# Epoch 76/99
# ----------
# train Loss: 1.3282 Acc: 0.2784
# val Loss: 1.4824 Acc: 0.2576
#
# Epoch 77/99
# ----------
# train Loss: 1.3220 Acc: 0.2843
# val Loss: 1.6218 Acc: 0.2576
#
# Epoch 78/99
# ----------
# train Loss: 1.3207 Acc: 0.2856
# val Loss: 1.4915 Acc: 0.2559
#
# Epoch 79/99
# ----------
# train Loss: 1.3177 Acc: 0.2877
# val Loss: 1.6084 Acc: 0.2525
#
# Epoch 80/99
# ----------
# train Loss: 1.3168 Acc: 0.2869
# val Loss: 1.6738 Acc: 0.2542
#
# Epoch 81/99
# ----------
# train Loss: 1.3162 Acc: 0.2881
# val Loss: 1.8354 Acc: 0.2576
#
# Epoch 82/99
# ----------
# train Loss: 1.3148 Acc: 0.2873
# val Loss: 1.5824 Acc: 0.2525
#
# Epoch 83/99
# ----------
# train Loss: 1.3145 Acc: 0.2864
# val Loss: 1.6760 Acc: 0.2525
#
# Epoch 84/99
# ----------
# train Loss: 1.3244 Acc: 0.2881
# val Loss: 1.4552 Acc: 0.2559
#
# Epoch 85/99
# ----------
# train Loss: 1.3171 Acc: 0.2860
# val Loss: 1.6105 Acc: 0.2542
#
# Epoch 86/99
# ----------
# train Loss: 1.3246 Acc: 0.2856
# val Loss: 1.6698 Acc: 0.2593
#
# Epoch 87/99
# ----------
# train Loss: 1.3118 Acc: 0.2894
# val Loss: 1.5884 Acc: 0.2559
#
# Epoch 88/99
# ----------
# train Loss: 1.3123 Acc: 0.2894
# val Loss: 1.8030 Acc: 0.2542
#
# Epoch 89/99
# ----------
# train Loss: 1.3047 Acc: 0.2924
# val Loss: 1.9479 Acc: 0.2542
#
# Epoch 90/99
# ----------
# train Loss: 1.3063 Acc: 0.2881
# val Loss: 1.9606 Acc: 0.2576
#
# Epoch 91/99
# ----------
# train Loss: 1.3022 Acc: 0.2932
# val Loss: 1.9698 Acc: 0.2559
#
# Epoch 92/99
# ----------
# train Loss: 1.3003 Acc: 0.2932
# val Loss: 1.7576 Acc: 0.2576
#
# Epoch 93/99
# ----------
# train Loss: 1.3046 Acc: 0.2949
# val Loss: 1.7752 Acc: 0.2508
#
# Epoch 94/99
# ----------
# train Loss: 1.3424 Acc: 0.2763
# val Loss: 1.4163 Acc: 0.2559
#
# Epoch 95/99
# ----------
# train Loss: 1.3188 Acc: 0.2877
# val Loss: 1.4787 Acc: 0.2593
#
# Epoch 96/99
# ----------
# train Loss: 1.3285 Acc: 0.2835
# val Loss: 1.6224 Acc: 0.2542
#
# Epoch 97/99
# ----------
# train Loss: 1.3212 Acc: 0.2873
# val Loss: 1.5320 Acc: 0.2593
#
# Epoch 98/99
# ----------
# train Loss: 1.3175 Acc: 0.2877
# val Loss: 1.7423 Acc: 0.2559
#
# Epoch 99/99
# ----------
# train Loss: 1.3079 Acc: 0.2915
# val Loss: 1.9549 Acc: 0.2593
#
# Training complete in 20m 53s
# Best val acc: 0.2627

# %% [markdown]
# # Computation using for loop

# %%
y_preds = []
y_true = []
for inputs, labels in test_loader:
    _, y_pred = torch.max(model(inputs), 1)
    y_preds.append(y_pred)
    y_true.append(labels)
y_preds = torch.cat(y_preds)
y_true = torch.cat(y_true)

# %%
print(y_preds.shape)
print(y_true.shape)
# Out:
# torch.Size([576])
# torch.Size([576])

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
cr = classification_report(y_true.cpu().numpy(), y_preds.cpu().numpy())
print(cr)

cm = confusion_matrix(y_true.cpu().numpy(), y_preds.cpu().numpy())
print(cm)

y_pred_ohe = np.zeros((y_preds.size(0), num_classes))
for i, j in enumerate(y_pred):
    y_pred_ohe[i, j] = 1

y_true_ohe = np.zeros((y_true.size(0), num_classes))
for i, j in enumerate(y_true):
    y_true_ohe[i, j] = 1
auroc = roc_auc_score(y_true_ohe, y_pred_ohe, multi_class='ovo')
writer.add_scalar('AUROC OvO', auroc)
print('AUROC ovo:', auroc)
auroc = roc_auc_score(y_true_ohe, y_pred_ohe, multi_class='ovr')
writer.add_scalar('AUROC OvR', auroc)
print('AUROC ovr:', auroc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       142
#            1       0.28      0.47      0.35       147
#            2       0.26      0.56      0.35       149
#            3       0.50      0.02      0.04       138
#
#     accuracy                           0.27       576
#    macro avg       0.26      0.26      0.19       576
# weighted avg       0.26      0.27      0.19       576
#
# [[ 0 67 75  0]
#  [ 0 69 78  0]
#  [ 0 63 83  3]
#  [ 0 48 87  3]]
# AUROC ovo: 0.5008893966110697
# AUROC ovr: 0.5008893966110697
# /home/amar/Desktop/thesis-2022/env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/amar/Desktop/thesis-2022/env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/amar/Desktop/thesis-2022/env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
{str(v): k for k, v in label_map.items()}
# Out:
# {'0': 'imagine_both_feet',
#  '1': 'imagine_both_fist',
#  '2': 'imagine_left_fist',
#  '3': 'imagine_right_fist'}

# %%
import seaborn as sns
import pandas as pd
import io

figure = plt.figure(figsize=(7, 5))
cm_df = pd.DataFrame(cm, columns=class_names, index=class_names)
sns.heatmap(cm_df, annot=True, fmt='g')
plt.ylabel('True')
plt.xlabel('Pred')
plt.tight_layout()
plt.savefig('runs/fcn/cm.png')
plt.show()

# %%
print('Number of trainable parameters')
sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# Number of trainable parameters
# 19350532

# %%
[p.numel() for p in model.parameters() if p.requires_grad]
# Out:
# [204800, 2048, 8388608, 4096, 8388608, 2048, 2097152, 1024, 262144, 4]
