# %%
import random
import torch
from torch import nn
import torch.nn.functional as F

import numpy as np 

from sklearn.model_selection import train_test_split
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

random_seed = 1
random.seed(random_seed)
np.random.seed(random_seed)
torch.manual_seed(random_seed)

from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter('runs/gnn_auto')

from utils import load_data, prepare_data
from utils import compute_adj_matrices
from utils import get_dataloaders

from layers_batchwise_2 import GraphConvolution

from utils import init_model_params

from utils import train_model

from utils import model_predict

from utils import print_classification_report

from utils import plot_cm

# %%
X, y, label_map = load_data('../dataset/train/cross_subject_data_5_subjects.pickle')
class_names = list(label_map.keys())

seq_len = 100
X, y = prepare_data(X, y, seq_len, normalize=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed, stratify=y)
# Out:
# X original shape: (295008, 64)
# y original shape: (295008,)
# Seq len: 100
# X conversion shape: (2950, 64, 100)
# y conversion shape: (2950,)

# %%
A = compute_adj_matrices('s')
print(A)
# Out:
# 64
# [[0.         0.07259316 0.0377163  ... 0.         0.         0.        ]
#  [0.07259316 0.         0.07242256 ... 0.         0.         0.        ]
#  [0.0377163  0.07242256 0.         ... 0.         0.         0.        ]
#  ...
#  [0.         0.         0.         ... 0.         0.10730997 0.10929675]
#  [0.         0.         0.         ... 0.10730997 0.         0.09523205]
#  [0.         0.         0.         ... 0.10929675 0.09523205 0.        ]]

# %%
batch_size = 32
dataloaders, dataset_sizes = get_dataloaders(X_train, y_train, X_test, y_test, batch_size)

# %%
in_features = seq_len
hidden_size_1 = 256
hidden_size_2 = 512
hidden_size_3 = 256
hidden_size_4 = 4
num_classes = 4
n_channels = 64

class GCN(nn.Module):
    def __init__(self, in_features, n_nodes, num_classes):
        super(GCN, self).__init__()
        self.gc1 = GraphConvolution(in_features, hidden_size_1, batch_size, n_channels)
        self.gc2 = GraphConvolution(hidden_size_1, hidden_size_2, batch_size, n_channels)
        self.gc3 = GraphConvolution(hidden_size_2, hidden_size_3, batch_size, n_channels)
        # self.gc4 = GraphConvolution(hidden_size_3, hidden_size_4, batch_size, n_channels)
        # self.flatten = nn.Flatten()
        # self.linear = nn.Linear(hidden_size_4*n_channels, num_classes)
        self.node_embeddings = nn.Parameter(torch.randn(n_nodes, n_nodes), requires_grad=True)
        self.flatten = nn.Flatten()
        self.linear = nn.Linear(hidden_size_3*n_channels, num_classes)

        self.node_embeddings = nn.Parameter(torch.randn(n_nodes, n_nodes), requires_grad=True)
    def forward(self, x):
        # print(x.shape)
        # A = F.softmax(F.relu(torch.mm(self.node_embeddings, self.node_embeddings.transpose(0, 1))), dim=1)
        # A = A + torch.eye(A.shape[0]).to(device)
        out = F.relu(self.gc1(x, self.node_embeddings))
        # print(out.shape)
        out = F.relu(self.gc2(out, self.node_embeddings))
        # print(out.shape)
        out = F.relu(self.gc3(out, self.node_embeddings))
        # print(out.shape)
        # out = F.relu(self.gc4(out, A))
        # print(out.shape)
        out = self.flatten(out)
        # print(out.shape)
        out = self.linear(out)
        # print(out.shape)
        return out


model = GCN(in_features=in_features, n_nodes=n_channels, num_classes=num_classes).to(device)


model = init_model_params(model)

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())


# writer.add_graph(model, X_train[:batch_size])

# %%
n_nodes = 64
node_num = n_nodes
node_embeddings = nn.Parameter(torch.randn(n_nodes, n_nodes), requires_grad=True)

supports = F.softmax(F.relu(torch.mm(node_embeddings, node_embeddings.transpose(0, 1))), dim=1)

# support_set = [torch.eye(node_num).to(supports.device), supports]

# supports = torch.stack(support_set, dim=0)

# supports.shape

# %%
supports
# Out:
# tensor([[1.0000e+00, 1.1913e-18, 1.2362e-16,  ..., 9.8738e-19, 1.9627e-18,
#          2.9142e-17],
#         [1.7008e-35, 1.0000e+00, 9.8243e-28,  ..., 1.1655e-28, 1.4097e-35,
#          1.4097e-35],
#         [2.7297e-21, 1.5195e-15, 1.0000e+00,  ..., 4.6472e-23, 4.3676e-21,
#          2.1803e-23],
#         ...,
#         [5.8648e-28, 4.8490e-21, 1.2501e-27,  ..., 1.0000e+00, 5.8648e-28,
#          5.8648e-28],
#         [1.1137e-25, 5.6028e-26, 1.1224e-23,  ..., 5.6028e-26, 1.0000e+00,
#          5.6028e-26],
#         [2.3880e-20, 8.0908e-22, 8.0908e-22,  ..., 8.0908e-22, 8.0908e-22,
#          1.0000e+00]], grad_fn=<SoftmaxBackward>)

# %%
num_epochs = 100
train_model(dataloaders, dataset_sizes, model, criterion, optimizer, num_epochs, writer)
# Out:
# Epoch 0/99
# ----------
# train Loss: 2.3946 Acc: 0.2453
# val Loss: 1.5911 Acc: 0.2525
#
# Epoch 1/99
# ----------
# train Loss: 1.4058 Acc: 0.3462
# val Loss: 1.4449 Acc: 0.2576
#
# Epoch 2/99
# ----------
# train Loss: 1.2459 Acc: 0.4242
# val Loss: 1.5421 Acc: 0.2424
#
# Epoch 3/99
# ----------
# train Loss: 1.1786 Acc: 0.4614
# val Loss: 1.4822 Acc: 0.2475
#
# Epoch 4/99
# ----------
# train Loss: 1.1257 Acc: 0.4894
# val Loss: 1.5597 Acc: 0.2475
#
# Epoch 5/99
# ----------
# train Loss: 1.0188 Acc: 0.5538
# val Loss: 1.7393 Acc: 0.2644
#
# Epoch 6/99
# ----------
# train Loss: 0.9012 Acc: 0.6119
# val Loss: 1.9150 Acc: 0.2847
#
# Epoch 7/99
# ----------
# train Loss: 0.8030 Acc: 0.6606
# val Loss: 1.9592 Acc: 0.2644
#
# Epoch 8/99
# ----------
# train Loss: 0.6859 Acc: 0.7072
# val Loss: 2.0318 Acc: 0.2593
#
# Epoch 9/99
# ----------
# train Loss: 0.6266 Acc: 0.7373
# val Loss: 2.2589 Acc: 0.2763
#
# Epoch 10/99
# ----------
# train Loss: 0.6067 Acc: 0.7568
# val Loss: 2.5688 Acc: 0.2780
#
# Epoch 11/99
# ----------
# train Loss: 0.5947 Acc: 0.7458
# val Loss: 2.5273 Acc: 0.2797
#
# Epoch 12/99
# ----------
# train Loss: 0.5156 Acc: 0.7928
# val Loss: 2.9788 Acc: 0.2627
#
# Epoch 13/99
# ----------
# train Loss: 0.5638 Acc: 0.7843
# val Loss: 3.2377 Acc: 0.2729
#
# Epoch 14/99
# ----------
# train Loss: 0.5080 Acc: 0.7924
# val Loss: 3.1336 Acc: 0.2966
#
# Epoch 15/99
# ----------
# train Loss: 0.4168 Acc: 0.8428
# val Loss: 3.5954 Acc: 0.3000
#
# Epoch 16/99
# ----------
# train Loss: 0.3659 Acc: 0.8610
# val Loss: 3.8634 Acc: 0.2695
#
# Epoch 17/99
# ----------
# train Loss: 0.2855 Acc: 0.8864
# val Loss: 3.7459 Acc: 0.3102
#
# Epoch 18/99
# ----------
# train Loss: 0.3150 Acc: 0.8831
# val Loss: 4.0134 Acc: 0.2678
#
# Epoch 19/99
# ----------
# train Loss: 0.2839 Acc: 0.8814
# val Loss: 4.2245 Acc: 0.2949
#
# Epoch 20/99
# ----------
# train Loss: 0.3458 Acc: 0.8835
# val Loss: 4.0699 Acc: 0.2729
#
# Epoch 21/99
# ----------
# train Loss: 0.3610 Acc: 0.8818
# val Loss: 4.9242 Acc: 0.2864
#
# Epoch 22/99
# ----------
# train Loss: 0.3653 Acc: 0.8682
# val Loss: 5.5334 Acc: 0.2797
#
# Epoch 23/99
# ----------
# train Loss: 0.3611 Acc: 0.8763
# val Loss: 5.0503 Acc: 0.2831
#
# Epoch 24/99
# ----------
# train Loss: 0.2562 Acc: 0.9059
# val Loss: 5.2695 Acc: 0.3136
#
# Epoch 25/99
# ----------
# train Loss: 0.2880 Acc: 0.9042
# val Loss: 5.3308 Acc: 0.2881
#
# Epoch 26/99
# ----------
# train Loss: 0.2029 Acc: 0.9335
# val Loss: 5.0771 Acc: 0.2915
#
# Epoch 27/99
# ----------
# train Loss: 0.2434 Acc: 0.9191
# val Loss: 5.9071 Acc: 0.3051
#
# Epoch 28/99
# ----------
# train Loss: 0.1153 Acc: 0.9551
# val Loss: 6.3658 Acc: 0.3254
#
# Epoch 29/99
# ----------
# train Loss: 0.1805 Acc: 0.9419
# val Loss: 5.7895 Acc: 0.3119
#
# Epoch 30/99
# ----------
# train Loss: 0.2036 Acc: 0.9263
# val Loss: 6.0933 Acc: 0.2915
#
# Epoch 31/99
# ----------
# train Loss: 0.1287 Acc: 0.9479
# val Loss: 6.8192 Acc: 0.2966
#
# Epoch 32/99
# ----------
# train Loss: 0.1250 Acc: 0.9521
# val Loss: 7.0212 Acc: 0.2966
#
# Epoch 33/99
# ----------
# train Loss: 0.4921 Acc: 0.8729
# val Loss: 6.1548 Acc: 0.3034
#
# Epoch 34/99
# ----------
# train Loss: 0.4599 Acc: 0.8555
# val Loss: 6.6130 Acc: 0.3136
#
# Epoch 35/99
# ----------
# train Loss: 0.2336 Acc: 0.9326
# val Loss: 5.6382 Acc: 0.3153
#
# Epoch 36/99
# ----------
# train Loss: 0.3959 Acc: 0.8992
# val Loss: 6.5000 Acc: 0.2966
#
# Epoch 37/99
# ----------
# train Loss: 0.2135 Acc: 0.9246
# val Loss: 6.3351 Acc: 0.3169
#
# Epoch 38/99
# ----------
# train Loss: 0.0480 Acc: 0.9737
# val Loss: 6.7031 Acc: 0.3339
#
# Epoch 39/99
# ----------
# train Loss: 0.0488 Acc: 0.9784
# val Loss: 6.7045 Acc: 0.2983
#
# Epoch 40/99
# ----------
# train Loss: 0.0406 Acc: 0.9784
# val Loss: 7.5881 Acc: 0.2915
#
# Epoch 41/99
# ----------
# train Loss: 0.0258 Acc: 0.9792
# val Loss: 7.6502 Acc: 0.2932
#
# Epoch 42/99
# ----------
# train Loss: 0.0055 Acc: 0.9886
# val Loss: 8.0584 Acc: 0.2763
#
# Epoch 43/99
# ----------
# train Loss: 0.0011 Acc: 0.9898
# val Loss: 8.1727 Acc: 0.2814
#
# Epoch 44/99
# ----------
# train Loss: 0.0006 Acc: 0.9898
# val Loss: 8.2238 Acc: 0.2814
#
# Epoch 45/99
# ----------
# train Loss: 0.0005 Acc: 0.9898
# val Loss: 8.2879 Acc: 0.2847
#
# Epoch 46/99
# ----------
# train Loss: 0.0004 Acc: 0.9898
# val Loss: 8.3578 Acc: 0.2881
#
# Epoch 47/99
# ----------
# train Loss: 0.0003 Acc: 0.9898
# val Loss: 8.4105 Acc: 0.2881
#
# Epoch 48/99
# ----------
# train Loss: 0.0003 Acc: 0.9898
# val Loss: 8.4641 Acc: 0.2864
#
# Epoch 49/99
# ----------
# train Loss: 0.0003 Acc: 0.9898
# val Loss: 8.5108 Acc: 0.2864
#
# Epoch 50/99
# ----------
# train Loss: 0.0003 Acc: 0.9898
# val Loss: 8.5554 Acc: 0.2915
#
# Epoch 51/99
# ----------
# train Loss: 0.0002 Acc: 0.9898
# val Loss: 8.5908 Acc: 0.2949
#
# Epoch 52/99
# ----------
# train Loss: 0.0002 Acc: 0.9898
# val Loss: 8.6282 Acc: 0.2949
#
# Epoch 53/99
# ----------
# train Loss: 0.0002 Acc: 0.9898
# val Loss: 8.6644 Acc: 0.2949
#
# Epoch 54/99
# ----------
# train Loss: 0.0002 Acc: 0.9898
# val Loss: 8.6982 Acc: 0.2949
#
# Epoch 55/99
# ----------
# train Loss: 0.0002 Acc: 0.9898
# val Loss: 8.7325 Acc: 0.2949
#
# Epoch 56/99
# ----------
# train Loss: 0.0002 Acc: 0.9898
# val Loss: 8.7652 Acc: 0.2949
#
# Epoch 57/99
# ----------
# train Loss: 0.0002 Acc: 0.9898
# val Loss: 8.7945 Acc: 0.2949
#
# Epoch 58/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 8.8215 Acc: 0.2949
#
# Epoch 59/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 8.8526 Acc: 0.2932
#
# Epoch 60/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 8.8808 Acc: 0.2915
#
# Epoch 61/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 8.9050 Acc: 0.2915
#
# Epoch 62/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 8.9348 Acc: 0.2915
#
# Epoch 63/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 8.9592 Acc: 0.2915
#
# Epoch 64/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 8.9789 Acc: 0.2932
#
# Epoch 65/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.0074 Acc: 0.2949
#
# Epoch 66/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.0292 Acc: 0.2949
#
# Epoch 67/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.0532 Acc: 0.2949
#
# Epoch 68/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.0773 Acc: 0.2949
#
# Epoch 69/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.0972 Acc: 0.2949
#
# Epoch 70/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.1199 Acc: 0.2966
#
# Epoch 71/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.1444 Acc: 0.2949
#
# Epoch 72/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.1678 Acc: 0.2949
#
# Epoch 73/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.1878 Acc: 0.2949
#
# Epoch 74/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.2120 Acc: 0.2949
#
# Epoch 75/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.2334 Acc: 0.2949
#
# Epoch 76/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.2545 Acc: 0.2966
#
# Epoch 77/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.2736 Acc: 0.2983
#
# Epoch 78/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.2995 Acc: 0.2966
#
# Epoch 79/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.3206 Acc: 0.2983
#
# Epoch 80/99
# ----------
# train Loss: 0.0001 Acc: 0.9898
# val Loss: 9.3407 Acc: 0.2983
#
# Epoch 81/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.3626 Acc: 0.3000
#
# Epoch 82/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.3836 Acc: 0.3017
#
# Epoch 83/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.4046 Acc: 0.3017
#
# Epoch 84/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.4238 Acc: 0.3000
#
# Epoch 85/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.4432 Acc: 0.2983
#
# Epoch 86/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.4635 Acc: 0.3000
#
# Epoch 87/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.4834 Acc: 0.3000
#
# Epoch 88/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.5021 Acc: 0.3000
#
# Epoch 89/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.5234 Acc: 0.3000
#
# Epoch 90/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.5429 Acc: 0.3000
#
# Epoch 91/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.5620 Acc: 0.2983
#
# Epoch 92/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.5811 Acc: 0.3000
#
# Epoch 93/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.6026 Acc: 0.3000
#
# Epoch 94/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.6187 Acc: 0.2983
#
# Epoch 95/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.6374 Acc: 0.2983
#
# Epoch 96/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.6583 Acc: 0.2983
#
# Epoch 97/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.6755 Acc: 0.2966
#
# Epoch 98/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.6946 Acc: 0.2966
#
# Epoch 99/99
# ----------
# train Loss: 0.0000 Acc: 0.9898
# val Loss: 9.7134 Acc: 0.2949
#
# Training complete in 0m 38s
# Best val acc: 0.3339
# GCN(
#   (gc1): GraphConvolution (100 -> 256)
#   (gc2): GraphConvolution (256 -> 512)
#   (gc3): GraphConvolution (512 -> 256)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear): Linear(in_features=16384, out_features=4, bias=True)
# )

# %%
import seaborn as sns
sns.heatmap(model.node_embeddings.cpu().detach().numpy())
# Out:
# <AxesSubplot:>

# %%
y_preds, y_test = model_predict(model, test_loader=dataloaders['val'])

# %%
cr, cm = print_classification_report(y_test, y_preds, num_classes, writer)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.35      0.33       142
#            1       0.39      0.36      0.37       147
#            2       0.38      0.40      0.39       149
#            3       0.34      0.30      0.32       138
#
#     accuracy                           0.35       576
#    macro avg       0.35      0.35      0.35       576
# weighted avg       0.36      0.35      0.35       576
#
# [[50 39 28 25]
#  [37 53 27 30]
#  [39 24 60 26]
#  [35 20 42 41]]
# AUROC ovo: 0.5688889451805571
# AUROC ovr: 0.5688889451805571

# %%
plot_cm(cm, class_names)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5491/81183290.py in <module>
# ----> 1 plot_cm(cm, class_names)
#
# TypeError: plot_cm() missing 1 required positional argument: 'save_path'

# %%
print('Number of trainable parameters')
print(sum(p.numel() for p in model.parameters() if p.requires_grad))
# Out:
# Number of trainable parameters
# 358404
