# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
train_hist = pickle.load(open("history_train.pickle", "rb"))
test_hist = pickle.load(open("history_test.pickle", "rb"))
train_hist = np.array(train_hist)
test_hist = np.array(test_hist)

# %%
len(train_hist)
# Out:
# 1000

# %%
len(test_hist)
# Out:
# 1000

# %%
plt.plot(test_hist[:, 0], test_hist[:, 1])
plt.show()

# %%
plt.plot(test_hist[:, 0], test_hist[:, 2])
plt.show()

# %%
plt.plot(test_hist[:, 0], test_hist[:, 3])
plt.show()

# %%
plt.plot(train_hist[:, 0], train_hist[:, 1])
plt.show()

# %%
plt.plot(train_hist[:, 0], train_hist[:, 2])
plt.show()
